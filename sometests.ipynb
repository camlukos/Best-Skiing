# %%
import pandas as pd
import requests

api_key = {'MNS8RP6DGCTYYBG2UHFLMTCQF'}
url = 'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/snowbird?unitGroup=us&key=MNS8RP6DGCTYYBG2UHFLMTCQF&contentType=json'
r=requests.get(url)

# %%
tahoe = pd.read_csv('Resources/tahoe.csv')
tahoe
# Out:
#          STATION                         NAME        DATE  DAPR  MDPR  PRCP  \
# 0    US1CAFR0022  SQUAW VALLEY 3.1 ESE, CA US  2018-01-04   NaN   NaN  0.07
# 1    US1CAFR0022  SQUAW VALLEY 3.1 ESE, CA US  2018-01-05   NaN   NaN  0.15
# 2    US1CAFR0022  SQUAW VALLEY 3.1 ESE, CA US  2018-01-06   NaN   NaN  0.02
# 3    US1CAFR0022  SQUAW VALLEY 3.1 ESE, CA US  2018-01-07   NaN   NaN  0.03
# 4    US1CAFR0022  SQUAW VALLEY 3.1 ESE, CA US  2018-01-08   NaN   NaN  0.21
# ..           ...                          ...         ...   ...   ...   ...
# 391  US1CAFR0021   SQUAW VALLEY 0.6 SE, CA US  2021-12-28   NaN   NaN  0.49
# 392  US1CAFR0021   SQUAW VALLEY 0.6 SE, CA US  2021-12-29   NaN   NaN  0.06
# 393  US1CAFR0021   SQUAW VALLEY 0.6 SE, CA US  2021-12-30   NaN   NaN  0.24
# 394  US1CAFR0021   SQUAW VALLEY 0.6 SE, CA US  2022-01-01   NaN   NaN  0.03
# 395  US1CAFR0021   SQUAW VALLEY 0.6 SE, CA US  2022-01-08   NaN   NaN  0.05
#
#      SNOW
# 0     NaN
# 1     NaN
# 2     NaN
# ...

# %%
tahoe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396 entries, 0 to 395
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  396 non-null    object
#  1   NAME     396 non-null    object
#  2   DATE     396 non-null    object
#  3   DAPR     9 non-null      float64
#  4   MDPR     9 non-null      float64
#  5   PRCP     387 non-null    float64
#  6   SNOW     10 non-null     float64
# dtypes: float64(4), object(3)
# memory usage: 21.8+ KB

# %%
tahoe = tahoe.dropna(subset=['SNOW'])
tahoe
# Out:
#          STATION                         NAME        DATE  DAPR  MDPR  PRCP  \
# 13   US1CAFR0022  SQUAW VALLEY 3.1 ESE, CA US  2018-02-23   NaN   NaN  0.14
# 14   US1CAFR0022  SQUAW VALLEY 3.1 ESE, CA US  2018-02-27   NaN   NaN  0.34
# 70   US1CAFR0022  SQUAW VALLEY 3.1 ESE, CA US  2019-02-11   NaN   NaN  0.25
# 75   US1CAFR0022  SQUAW VALLEY 3.1 ESE, CA US  2019-02-17   NaN   NaN  0.34
# 76   US1CAFR0022  SQUAW VALLEY 3.1 ESE, CA US  2019-02-18   NaN   NaN  0.33
# 77   US1CAFR0022  SQUAW VALLEY 3.1 ESE, CA US  2019-02-21   NaN   NaN  0.02
# 121  US1CAFR0022  SQUAW VALLEY 3.1 ESE, CA US  2020-01-17   NaN   NaN  0.73
# 160  US1CAFR0022  SQUAW VALLEY 3.1 ESE, CA US  2021-01-25   NaN   NaN  0.65
# 161  US1CAFR0022  SQUAW VALLEY 3.1 ESE, CA US  2021-01-26   NaN   NaN  0.39
# 170  US1CAFR0022  SQUAW VALLEY 3.1 ESE, CA US  2021-03-11   NaN   NaN  1.47
#
#      SNOW
# 13    0.5
# 14    1.8
# 70    1.5
# 75    1.0
# 76    4.5
# 77    0.5
# 121   0.5
# 160   1.0
# 161   2.0
# 170   3.0
