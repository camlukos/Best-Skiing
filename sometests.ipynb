# %%
import pandas as pd
import requests

api_key = {'MNS8RP6DGCTYYBG2UHFLMTCQF'}
url = 'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/snowbird?unitGroup=us&key=MNS8RP6DGCTYYBG2UHFLMTCQF&contentType=json'
r=requests.get(url)
json = r.json()
json
# Out:
# {'queryCost': 1,
#  'latitude': 37.64559,
#  'longitude': -119.00022,
#  'resolvedAddress': 'Snowbird, Mammoth Lakes, CA, United States',
#  'address': 'snowbird',
#  'timezone': 'America/Los_Angeles',
#  'tzoffset': -8.0,
#  'description': 'Similar temperatures continuing with no rain expected.',
#  'days': [{'datetime': '2022-01-15',
#    'datetimeEpoch': 1642233600,
#    'tempmax': 38.0,
#    'tempmin': 9.7,
#    'temp': 26.6,
#    'feelslikemax': 34.4,
#    'feelslikemin': 4.9,
#    'feelslike': 22.8,
#    'dew': 9.5,
#    'humidity': 50.9,
#    'precip': 0.0,
#    'precipprob': 1.0,
#    'precipcover': None,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 44.6,
#    'windgust': 11.4,
#    'windspeed': 6.9,
#    'winddir': 153.6,
#    'pressure': 1026.6,
#    'cloudcover': 37.1,
#    'visibility': 12.7,
#    'solarradiation': 135.7,
#    'solarenergy': 8.2,
#    'uvindex': 4.0,
#    'severerisk': 10.0,
#    'sunrise': '07:09:55',
#    'sunriseEpoch': 1642259395,
#    'sunset': '17:01:28',
#    'sunsetEpoch': 1642294888,
#    'moonphase': 0.47,
#    'conditions': 'Partially cloudy',
#    'description': 'Partly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'stations': ['SE388', 'KBIH', 'KMMH'],
#    'source': 'comb',
#    'hours': [{'datetime': '00:00:00',
#      'datetimeEpoch': 1642233600,
#      'temp': 34.1,
#      'feelslike': 28.0,
#      'humidity': 60.5,
#      'dew': 21.8,
#      'precip': None,
#      'precipprob': None,
#      'snow': None,
#      'snowdepth': None,
#      'preciptype': None,
#      'windgust': None,
#      'windspeed': 6.9,
#      'winddir': 320.0,
#      'pressure': 1029.2,
#      'visibility': 9.9,
#      'cloudcover': 0.0,
#      'solarradiation': None,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'conditions': 'Clear',
#      'icon': 'clear-night',
#      'stations': ['KBIH'],
#      'source': 'obs'},
#     {'datetime': '01:00:00',
#      'datetimeEpoch': 1642237200,
#      'temp': 18.4,
#      'feelslike': 13.0,
#      'humidity': 77.94,
#      'dew': 12.6,
#      'precip': None,
#      'precipprob': None,
#      'snow': None,
#      'snowdepth': None,
#      'preciptype': None,
#      'windgust': None,
#      'windspeed': 3.6,
#      'winddir': 339.0,
#      'pressure': 1030.7,
#      'visibility': 9.9,
#      'cloudcover': 0.0,
#      'solarradiation': None,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'conditions': 'Clear',
#      'icon': 'clear-night',
#      'stations': ['KBIH', 'KMMH'],
#      'source': 'obs'},
#     {'datetime': '02:00:00',
#      'datetimeEpoch': 1642240800,
#      'temp': 16.6,
#      'feelslike': 16.6,
#      'humidity': 77.84,
#      'dew': 10.9,
#      'precip': None,
#      'precipprob': None,
#      'snow': None,
#      'snowdepth': None,
#      'preciptype': None,
#      'windgust': None,
#      'windspeed': 0.5,
#      'winddir': 357.0,
#      'pressure': 1031.1,
#      'visibility': 9.9,
#      'cloudcover': 0.0,
#      'solarradiation': None,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'conditions': 'Clear',
#      'icon': 'clear-night',
#      'stations': ['KBIH', 'KMMH'],
#      'source': 'obs'},
#     {'datetime': '03:00:00',
#      'datetimeEpoch': 1642244400,
#      'temp': 11.5,
#      'feelslike': 4.9,
#      'humidity': 90.22,
#      'dew': 9.2,
#      'precip': None,
#      'precipprob': None,
#      'snow': None,
#      'snowdepth': None,
#      'preciptype': None,
#      'windgust': None,
#      'windspeed': 3.7,
#      'winddir': 338.0,
#      'pressure': 1031.1,
#      'visibility': 9.9,
#      'cloudcover': 0.0,
#      'solarradiation': None,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'conditions': 'Clear',
#      'icon': 'clear-night',
#      'stations': ['KBIH', 'KMMH'],
#      'source': 'obs'},
#     {'datetime': '04:00:00',
#      'datetimeEpoch': 1642248000,
#      'temp': 11.5,
#      'feelslike': 11.5,
#      'humidity': 83.57,
#      'dew': 7.5,
#      'precip': None,
#      'precipprob': None,
#      'snow': None,
#      'snowdepth': None,
#      'preciptype': None,
#      'windgust': None,
#      'windspeed': None,
#      'winddir': None,
#      'pressure': 1030.7,
#      'visibility': 9.9,
#      'cloudcover': 0.0,
#      'solarradiation': None,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'conditions': 'Clear',
#      'icon': 'clear-night',
#      'stations': ['KBIH', 'KMMH'],
#      'source': 'obs'},
#     {'datetime': '05:00:00',
#      'datetimeEpoch': 1642251600,
#      'temp': 11.6,
#      'feelslike': 11.6,
#      'humidity': 77.12,
#      'dew': 5.8,
#      'precip': None,
#      'precipprob': None,
#      'snow': None,
#      'snowdepth': None,
#      'preciptype': None,
#      'windgust': None,
#      'windspeed': 0.4,
#      'winddir': 357.0,
#      'pressure': 1030.4,
#      'visibility': 9.9,
#      'cloudcover': 0.0,
#      'solarradiation': None,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'conditions': 'Clear',
#      'icon': 'clear-night',
#      'stations': ['KBIH', 'KMMH'],
#      'source': 'obs'},
#     {'datetime': '06:00:00',
#      'datetimeEpoch': 1642255200,
#      'temp': 9.7,
#      'feelslike': 9.7,
#      'humidity': 90.18,
#      'dew': 7.4,
#      'precip': None,
#      'precipprob': None,
#      'snow': None,
#      'snowdepth': None,
#      'preciptype': None,
#      'windgust': None,
#      'windspeed': 0.4,
#      'winddir': 357.0,
#      'pressure': 1030.7,
#      'visibility': 9.9,
#      'cloudcover': 0.0,
#      'solarradiation': None,
#      'solarenergy': None,
#      'uvindex': 0.0,
#      'conditions': 'Clear',
#      'icon': 'clear-night',
#      'stations': ['KBIH', 'KMMH'],
#      'source': 'obs'},
#     {'datetime': '07:00:00',
#      'datetimeEpoch': 1642258800,
#      'temp': 13.4,
#      'feelslike': 13.4,
#      'humidity': 76.74,
#      'dew': 7.4,
#      'precip': None,
#      'precipprob': None,
#      'snow': None,
#      'snowdepth': None,
#      'preciptype': None,
#      'windgust': None,
#      'windspeed': 0.6,
#      'winddir': 358.0,
#      'pressure': 1031.1,
#      'visibility': 9.9,
#      'cloudcover': 0.0,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'conditions': 'Clear',
#      'icon': 'clear-night',
#      'stations': ['SE388', 'KBIH', 'KMMH'],
#      'source': 'obs'},
#     {'datetime': '08:00:00',
#      'datetimeEpoch': 1642262400,
#      'temp': 9.9,
#      'feelslike': 9.9,
#      'humidity': 83.0,
#      'dew': 5.7,
#      'precip': None,
#      'precipprob': None,
#      'snow': None,
#      'snowdepth': None,
#      'preciptype': None,
#      'windgust': None,
#      'windspeed': 0.4,
#      'winddir': 357.0,
#      'pressure': 1031.2,
#      'visibility': 9.9,
#      'cloudcover': 0.0,
#      'solarradiation': 30.0,
#      'solarenergy': 0.1,
#      'uvindex': 0.0,
#      'conditions': 'Clear',
#      'icon': 'clear-day',
#      'stations': ['SE388', 'KBIH', 'KMMH'],
#      'source': 'obs'},
#     {'datetime': '09:00:00',
#      'datetimeEpoch': 1642266000,
#      'temp': 34.1,
#      'feelslike': 28.8,
#      'humidity': 35.0,
#      'dew': 19.3,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 52.3,
#      'preciptype': None,
#      'windgust': 11.4,
#      'windspeed': 5.8,
#      'winddir': 80.0,
#      'pressure': 1025.0,
#      'visibility': 15.0,
#      'cloudcover': 72.0,
#      'solarradiation': 70.0,
#      'solarenergy': 0.3,
#      'uvindex': 1.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '10:00:00',
#      'datetimeEpoch': 1642269600,
#      'temp': 36.9,
#      'feelslike': 33.1,
#      'humidity': 41.0,
#      'dew': 24.3,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 50.8,
#      'preciptype': None,
#      'windgust': 11.4,
#      'windspeed': 4.7,
#      'winddir': 40.0,
#      'pressure': 1024.0,
#      'visibility': 15.0,
#      'cloudcover': 58.0,
#      'solarradiation': 284.0,
#      'solarenergy': 1.0,
#      'uvindex': 3.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '11:00:00',
#      'datetimeEpoch': 1642273200,
#      'temp': 36.9,
#      'feelslike': 33.1,
#      'humidity': 40.0,
#      'dew': 32.1,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 48.2,
#      'preciptype': None,
#      'windgust': 11.4,
#      'windspeed': 4.7,
#      'winddir': 30.0,
#      'pressure': 1023.0,
#      'visibility': 9.9,
#      'cloudcover': 59.0,
#      'solarradiation': 365.0,
#      'solarenergy': 1.3,
#      'uvindex': 4.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '12:00:00',
#      'datetimeEpoch': 1642276800,
#      'temp': 38.0,
#      'feelslike': 34.4,
#      'humidity': 42.0,
#      'dew': 33.7,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 45.9,
#      'preciptype': None,
#      'windgust': 11.4,
#      'windspeed': 4.7,
#      'winddir': 40.0,
#      'pressure': 1022.0,
#      'visibility': 13.3,
#      'cloudcover': 40.0,
#      'solarradiation': 400.0,
#      'solarenergy': 1.4,
#      'uvindex': 4.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '13:00:00',
#      'datetimeEpoch': 1642280400,
#      'temp': 36.9,
#      'feelslike': 33.1,
#      'humidity': 44.0,
#      'dew': 31.9,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 43.9,
#      'preciptype': None,
#      'windgust': 11.4,
#      'windspeed': 4.7,
#      'winddir': 30.0,
#      'pressure': 1021.0,
#      'visibility': 12.0,
#      'cloudcover': 42.0,
#      'solarradiation': 403.0,
#      'solarenergy': 1.5,
#      'uvindex': 4.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '14:00:00',
#      'datetimeEpoch': 1642284000,
#      'temp': 36.0,
#      'feelslike': 32.1,
#      'humidity': 43.0,
#      'dew': 20.6,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 43.5,
#      'preciptype': None,
#      'windgust': 11.4,
#      'windspeed': 4.7,
#      'winddir': 30.0,
#      'pressure': 1021.0,
#      'visibility': 14.5,
#      'cloudcover': 42.0,
#      'solarradiation': 352.0,
#      'solarenergy': 1.3,
#      'uvindex': 4.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '15:00:00',
#      'datetimeEpoch': 1642287600,
#      'temp': 36.0,
#      'feelslike': 31.2,
#      'humidity': 40.0,
#      'dew': 16.2,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 43.3,
#      'preciptype': None,
#      'windgust': 10.3,
#      'windspeed': 5.8,
#      'winddir': 40.0,
#      'pressure': 1022.0,
#      'visibility': 15.0,
#      'cloudcover': 59.0,
#      'solarradiation': 312.0,
#      'solarenergy': 1.1,
#      'uvindex': 3.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '16:00:00',
#      'datetimeEpoch': 1642291200,
#      'temp': 33.0,
#      'feelslike': 28.5,
#      'humidity': 34.0,
#      'dew': 6.3,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 43.1,
#      'preciptype': None,
#      'windgust': 10.3,
#      'windspeed': 4.7,
#      'winddir': 60.0,
#      'pressure': 1024.0,
#      'visibility': 15.0,
#      'cloudcover': 62.0,
#      'solarradiation': 38.0,
#      'solarenergy': 0.1,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '17:00:00',
#      'datetimeEpoch': 1642294800,
#      'temp': 31.9,
#      'feelslike': 26.3,
#      'humidity': 28.0,
#      'dew': -6.3,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 43.0,
#      'preciptype': None,
#      'windgust': 10.3,
#      'windspeed': 5.8,
#      'winddir': 60.0,
#      'pressure': 1026.0,
#      'visibility': 15.0,
#      'cloudcover': 57.0,
#      'solarradiation': 19.0,
#      'solarenergy': 0.1,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '18:00:00',
#      'datetimeEpoch': 1642298400,
#      'temp': 31.0,
#      'feelslike': 25.2,
#      'humidity': 28.0,
#      'dew': -11.8,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 42.9,
#      'preciptype': None,
#      'windgust': 10.3,
#      'windspeed': 5.8,
#      'winddir': 70.0,
#      'pressure': 1028.0,
#      'visibility': 15.0,
#      'cloudcover': 65.0,
#      'solarradiation': 12.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '19:00:00',
#      'datetimeEpoch': 1642302000,
#      'temp': 31.0,
#      'feelslike': 25.2,
#      'humidity': 26.0,
#      'dew': -8.6,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 42.8,
#      'preciptype': None,
#      'windgust': 10.3,
#      'windspeed': 5.8,
#      'winddir': 60.0,
#      'pressure': 1027.0,
#      'visibility': 15.0,
#      'cloudcover': 68.0,
#      'solarradiation': 9.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '20:00:00',
#      'datetimeEpoch': 1642305600,
#      'temp': 29.9,
#      'feelslike': 23.9,
#      'humidity': 26.0,
#      'dew': -10.2,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 42.6,
#      'preciptype': None,
#      'windgust': 10.3,
#      'windspeed': 5.8,
#      'winddir': 60.0,
#      'pressure': 1027.0,
#      'visibility': 15.0,
#      'cloudcover': 56.0,
#      'solarradiation': 7.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '21:00:00',
#      'datetimeEpoch': 1642309200,
#      'temp': 29.9,
#      'feelslike': 24.9,
#      'humidity': 26.0,
#      'dew': -10.8,
#      'precip': 0.0,
#      'precipprob': 1.0,
#      'snow': 0.0,
#      'snowdepth': 42.5,
#      'preciptype': None,
#      'windgust': 8.1,
#      'windspeed': 4.7,
#      'winddir': 50.0,
#      'pressure': 1027.0,
#      'visibility': 15.0,
#      'cloudcover': 70.0,
#      'solarradiation': 6.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '22:00:00',
#      'datetimeEpoch': 1642312800,
#      'temp': 29.9,
#      'feelslike': 24.9,
#      'humidity': 25.0,
#      'dew': -0.3,
#      'precip': 0.0,
#      'precipprob': 1.0,
#      'snow': 0.0,
#      'snowdepth': 42.4,
#      'preciptype': None,
#      'windgust': 8.1,
#      'windspeed': 4.7,
#      'winddir': 50.0,
#      'pressure': 1024.0,
#      'visibility': 15.0,
#      'cloudcover': 70.0,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '23:00:00',
#      'datetimeEpoch': 1642316400,
#      'temp': 29.9,
#      'feelslike': 24.9,
#      'humidity': 26.0,
#      'dew': 4.4,
#      'precip': 0.0,
#      'precipprob': 1.0,
#      'snow': 0.0,
#      'snowdepth': 42.2,
#      'preciptype': None,
#      'windgust': 8.1,
#      'windspeed': 4.7,
#      'winddir': 50.0,
#      'pressure': 1022.0,
#      'visibility': 15.0,
#      'cloudcover': 70.0,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'}]},
#   {'datetime': '2022-01-16',
#    'datetimeEpoch': 1642320000,
#    'tempmax': 36.0,
#    'tempmin': 29.0,
#    'temp': 31.4,
#    'feelslikemax': 35.0,
#    'feelslikemin': 22.8,
#    'feelslike': 27.4,
#    'dew': 19.0,
#    'humidity': 39.5,
#    'precip': 0.0,
#    'precipprob': 3.0,
#    'precipcover': None,
#    'preciptype': None,
#    'snow': 0.0,
#    'snowdepth': 36.9,
#    'windgust': 10.3,
#    'windspeed': 5.8,
#    'winddir': 242.9,
#    'pressure': 1021.3,
#    'cloudcover': 36.0,
#    'visibility': 12.2,
#    'solarradiation': 123.6,
#    'solarenergy': 10.6,
#    'uvindex': 5.0,
#    'severerisk': 10.0,
#    'sunrise': '07:09:34',
#    'sunriseEpoch': 1642345774,
#    'sunset': '17:02:31',
#    'sunsetEpoch': 1642381351,
#    'moonphase': 0.49,
#    'conditions': 'Partially cloudy',
#    'description': 'Partly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'stations': None,
#    'source': 'fcst',
#    'hours': [{'datetime': '00:00:00',
#      'datetimeEpoch': 1642320000,
#      'temp': 29.9,
#      'feelslike': 24.9,
#      'humidity': 25.0,
#      'dew': 3.5,
#      'precip': 0.0,
#      'precipprob': 1.0,
#      'snow': 0.0,
#      'snowdepth': 42.1,
#      'preciptype': None,
#      'windgust': 6.9,
#      'windspeed': 4.7,
#      'winddir': 180.0,
#      'pressure': 1022.0,
#      'visibility': 15.0,
#      'cloudcover': 51.0,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '01:00:00',
#      'datetimeEpoch': 1642323600,
#      'temp': 29.9,
#      'feelslike': 24.9,
#      'humidity': 28.0,
#      'dew': 4.0,
#      'precip': 0.0,
#      'precipprob': 1.0,
#      'snow': 0.0,
#      'snowdepth': 41.9,
#      'preciptype': None,
#      'windgust': 6.9,
#      'windspeed': 4.7,
#      'winddir': 180.0,
#      'pressure': 1023.0,
#      'visibility': 15.0,
#      'cloudcover': 51.0,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '02:00:00',
#      'datetimeEpoch': 1642327200,
#      'temp': 29.0,
#      'feelslike': 23.9,
#      'humidity': 32.0,
#      'dew': 8.3,
#      'precip': 0.0,
#      'precipprob': 1.0,
#      'snow': 0.0,
#      'snowdepth': 41.8,
#      'preciptype': None,
#      'windgust': 6.9,
#      'windspeed': 4.7,
#      'winddir': 180.0,
#      'pressure': 1023.0,
#      'visibility': 15.0,
#      'cloudcover': 51.0,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '03:00:00',
#      'datetimeEpoch': 1642330800,
#      'temp': 29.0,
#      'feelslike': 22.8,
#      'humidity': 34.0,
#      'dew': 13.2,
#      'precip': 0.0,
#      'precipprob': 3.0,
#      'snow': 0.0,
#      'snowdepth': 41.7,
#      'preciptype': None,
#      'windgust': 8.1,
#      'windspeed': 5.8,
#      'winddir': 170.0,
#      'pressure': 1022.0,
#      'visibility': 15.0,
#      'cloudcover': 47.0,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '04:00:00',
#      'datetimeEpoch': 1642334400,
#      'temp': 29.0,
#      'feelslike': 22.8,
#      'humidity': 32.0,
#      'dew': 14.8,
#      'precip': 0.0,
#      'precipprob': 3.0,
#      'snow': 0.0,
#      'snowdepth': 41.6,
#      'preciptype': None,
#      'windgust': 8.1,
#      'windspeed': 5.8,
#      'winddir': 170.0,
#      'pressure': 1022.0,
#      'visibility': 15.0,
#      'cloudcover': 47.0,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '05:00:00',
#      'datetimeEpoch': 1642338000,
#      'temp': 29.0,
#      'feelslike': 22.8,
#      'humidity': 29.0,
#      'dew': 16.4,
#      'precip': 0.0,
#      'precipprob': 3.0,
#      'snow': 0.0,
#      'snowdepth': 41.5,
#      'preciptype': None,
#      'windgust': 8.1,
#      'windspeed': 5.8,
#      'winddir': 170.0,
#      'pressure': 1023.0,
#      'visibility': 15.0,
#      'cloudcover': 47.0,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '06:00:00',
#      'datetimeEpoch': 1642341600,
#      'temp': 29.9,
#      'feelslike': 24.9,
#      'humidity': 27.0,
#      'dew': 17.0,
#      'precip': 0.0,
#      'precipprob': 3.0,
#      'snow': 0.0,
#      'snowdepth': 41.4,
#      'preciptype': None,
#      'windgust': 8.1,
#      'windspeed': 4.7,
#      'winddir': 50.0,
#      'pressure': 1023.0,
#      'visibility': 15.0,
#      'cloudcover': 38.0,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '07:00:00',
#      'datetimeEpoch': 1642345200,
#      'temp': 31.0,
#      'feelslike': 26.2,
#      'humidity': 29.0,
#      'dew': 20.2,
#      'precip': 0.0,
#      'precipprob': 3.0,
#      'snow': 0.0,
#      'snowdepth': 41.3,
#      'preciptype': None,
#      'windgust': 8.1,
#      'windspeed': 4.7,
#      'winddir': 50.0,
#      'pressure': 1022.0,
#      'visibility': 15.0,
#      'cloudcover': 38.0,
#      'solarradiation': 7.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '08:00:00',
#      'datetimeEpoch': 1642348800,
#      'temp': 31.9,
#      'feelslike': 27.3,
#      'humidity': 34.0,
#      'dew': 28.5,
#      'precip': 0.0,
#      'precipprob': 3.0,
#      'snow': 0.0,
#      'snowdepth': 41.1,
#      'preciptype': None,
#      'windgust': 8.1,
#      'windspeed': 4.7,
#      'winddir': 50.0,
#      'pressure': 1019.0,
#      'visibility': 15.0,
#      'cloudcover': 38.0,
#      'solarradiation': 45.0,
#      'solarenergy': 0.2,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '09:00:00',
#      'datetimeEpoch': 1642352400,
#      'temp': 33.0,
#      'feelslike': 33.0,
#      'humidity': 39.0,
#      'dew': 31.2,
#      'precip': 0.0,
#      'precipprob': 3.0,
#      'snow': 0.0,
#      'snowdepth': 39.7,
#      'preciptype': None,
#      'windgust': 5.8,
#      'windspeed': 2.2,
#      'winddir': 330.0,
#      'pressure': 1019.0,
#      'visibility': 6.8,
#      'cloudcover': 20.0,
#      'solarradiation': 98.0,
#      'solarenergy': 0.4,
#      'uvindex': 1.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '10:00:00',
#      'datetimeEpoch': 1642356000,
#      'temp': 34.1,
#      'feelslike': 34.1,
#      'humidity': 43.0,
#      'dew': 31.5,
#      'precip': 0.0,
#      'precipprob': 3.0,
#      'snow': 0.0,
#      'snowdepth': 38.1,
#      'preciptype': None,
#      'windgust': 5.8,
#      'windspeed': 2.2,
#      'winddir': 330.0,
#      'pressure': 1019.0,
#      'visibility': 0.1,
#      'cloudcover': 20.0,
#      'solarradiation': 476.0,
#      'solarenergy': 1.7,
#      'uvindex': 5.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'fog',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '11:00:00',
#      'datetimeEpoch': 1642359600,
#      'temp': 35.0,
#      'feelslike': 35.0,
#      'humidity': 45.0,
#      'dew': 30.6,
#      'precip': 0.0,
#      'precipprob': 3.0,
#      'snow': 0.0,
#      'snowdepth': 36.7,
#      'preciptype': None,
#      'windgust': 5.8,
#      'windspeed': 2.2,
#      'winddir': 330.0,
#      'pressure': 1019.0,
#      'visibility': 0.0,
#      'cloudcover': 20.0,
#      'solarradiation': 472.0,
#      'solarenergy': 1.7,
#      'uvindex': 5.0,
#      'severerisk': 10.0,
#      'conditions': 'Clear',
#      'icon': 'clear-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '12:00:00',
#      'datetimeEpoch': 1642363200,
#      'temp': 36.0,
#      'feelslike': 33.5,
#      'humidity': 48.0,
#      'dew': 29.7,
#      'precip': 0.0,
#      'precipprob': 3.0,
#      'snow': 0.0,
#      'snowdepth': 35.3,
#      'preciptype': None,
#      'windgust': 10.3,
#      'windspeed': 3.4,
#      'winddir': 280.0,
#      'pressure': 1018.0,
#      'visibility': 0.1,
#      'cloudcover': 21.0,
#      'solarradiation': 455.0,
#      'solarenergy': 1.6,
#      'uvindex': 5.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'fog',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '13:00:00',
#      'datetimeEpoch': 1642366800,
#      'temp': 36.0,
#      'feelslike': 33.5,
#      'humidity': 48.0,
#      'dew': 28.7,
#      'precip': 0.0,
#      'precipprob': 3.0,
#      'snow': 0.0,
#      'snowdepth': 34.1,
#      'preciptype': None,
#      'windgust': 10.3,
#      'windspeed': 3.4,
#      'winddir': 280.0,
#      'pressure': 1018.0,
#      'visibility': 2.5,
#      'cloudcover': 21.0,
#      'solarradiation': 440.0,
#      'solarenergy': 1.6,
#      'uvindex': 4.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '14:00:00',
#      'datetimeEpoch': 1642370400,
#      'temp': 35.0,
#      'feelslike': 32.2,
#      'humidity': 49.0,
#      'dew': 27.8,
#      'precip': 0.0,
#      'precipprob': 3.0,
#      'snow': 0.0,
#      'snowdepth': 33.0,
#      'preciptype': None,
#      'windgust': 10.3,
#      'windspeed': 3.4,
#      'winddir': 280.0,
#      'pressure': 1017.0,
#      'visibility': 13.5,
#      'cloudcover': 21.0,
#      'solarradiation': 429.0,
#      'solarenergy': 1.5,
#      'uvindex': 4.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '15:00:00',
#      'datetimeEpoch': 1642374000,
#      'temp': 34.1,
#      'feelslike': 31.2,
#      'humidity': 49.0,
#      'dew': 25.6,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 32.9,
#      'preciptype': None,
#      'windgust': 8.1,
#      'windspeed': 3.4,
#      'winddir': 290.0,
#      'pressure': 1017.0,
#      'visibility': 15.0,
#      'cloudcover': 30.0,
#      'solarradiation': 397.0,
#      'solarenergy': 1.4,
#      'uvindex': 4.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '16:00:00',
#      'datetimeEpoch': 1642377600,
#      'temp': 32.6,
#      'feelslike': 29.0,
#      'humidity': 49.0,
#      'dew': 16.2,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 32.8,
#      'preciptype': None,
#      'windgust': 7.6,
#      'windspeed': 3.8,
#      'winddir': 300.0,
#      'pressure': 1021.0,
#      'visibility': 15.0,
#      'cloudcover': 33.0,
#      'solarradiation': 60.0,
#      'solarenergy': 0.2,
#      'uvindex': 1.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '17:00:00',
#      'datetimeEpoch': 1642381200,
#      'temp': 31.4,
#      'feelslike': 27.1,
#      'humidity': 49.0,
#      'dew': 14.4,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 32.8,
#      'preciptype': None,
#      'windgust': 7.4,
#      'windspeed': 4.3,
#      'winddir': 310.0,
#      'pressure': 1023.0,
#      'visibility': 15.0,
#      'cloudcover': 35.0,
#      'solarradiation': 30.0,
#      'solarenergy': 0.1,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '18:00:00',
#      'datetimeEpoch': 1642384800,
#      'temp': 29.9,
#      'feelslike': 24.9,
#      'humidity': 47.0,
#      'dew': 15.0,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'snow': 0.0,
#      'snowdepth': 32.8,
#      'preciptype': None,
#      'windgust': 6.9,
#      'windspeed': 4.7,
#      'winddir': 320.0,
#      'pressure': 1023.0,
#      'visibility': 15.0,
#      'cloudcover': 38.0,
#      'solarradiation': 20.0,
#      'solarenergy': 0.1,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '19:00:00',
#      'datetimeEpoch': 1642388400,
#      'temp': 29.9,
#      'feelslike': 24.9,
#      'humidity': 47.0,
#      'dew': 15.3,
#      'precip': 0.0,
#      'precipprob': 0.3,
#      'snow': 0.0,
#      'snowdepth': 32.7,
#      'preciptype': None,
#      'windgust': 6.9,
#      'windspeed': 4.7,
#      'winddir': 320.0,
#      'pressure': 1023.0,
#      'visibility': 15.0,
#      'cloudcover': 38.0,
#      'solarradiation': 15.0,
#      'solarenergy': 0.1,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '20:00:00',
#      'datetimeEpoch': 1642392000,
#      'temp': 29.9,
#      'feelslike': 24.9,
#      'humidity': 47.0,
#      'dew': 15.3,
#      'precip': 0.0,
#      'precipprob': 0.7,
#      'snow': 0.0,
#      'snowdepth': 32.7,
#      'preciptype': None,
#      'windgust': 6.9,
#      'windspeed': 4.7,
#      'winddir': 320.0,
#      'pressure': 1024.0,
#      'visibility': 15.0,
#      'cloudcover': 39.0,
#      'solarradiation': 12.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '21:00:00',
#      'datetimeEpoch': 1642395600,
#      'temp': 29.9,
#      'feelslike': 24.9,
#      'humidity': 39.0,
#      'dew': 15.5,
#      'precip': 0.0,
#      'precipprob': 1.0,
#      'snow': 0.0,
#      'snowdepth': 32.6,
#      'preciptype': None,
#      'windgust': 6.9,
#      'windspeed': 4.7,
#      'winddir': 320.0,
#      'pressure': 1024.0,
#      'visibility': 15.0,
#      'cloudcover': 39.0,
#      'solarradiation': 10.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '22:00:00',
#      'datetimeEpoch': 1642399200,
#      'temp': 29.6,
#      'feelslike': 24.5,
#      'humidity': 39.0,
#      'dew': 16.4,
#      'precip': 0.0,
#      'precipprob': 1.0,
#      'snow': 0.0,
#      'snowdepth': 32.6,
#      'preciptype': None,
#      'windgust': 7.4,
#      'windspeed': 4.7,
#      'winddir': 313.3,
#      'pressure': 1023.0,
#      'visibility': 15.0,
#      'cloudcover': 40.0,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '23:00:00',
#      'datetimeEpoch': 1642402800,
#      'temp': 29.4,
#      'feelslike': 24.3,
#      'humidity': 39.0,
#      'dew': 16.2,
#      'precip': 0.0,
#      'precipprob': 1.0,
#      'snow': 0.0,
#      'snowdepth': 32.6,
#      'preciptype': None,
#      'windgust': 7.6,
#      'windspeed': 4.7,
#      'winddir': 306.7,
#      'pressure': 1023.0,
#      'visibility': 15.0,
#      'cloudcover': 42.0,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'}]},
#   {'datetime': '2022-01-17',
#    'datetimeEpoch': 1642406400,
#    'tempmax': 34.1,
#    'tempmin': 27.0,
#    'temp': 30.0,
#    'feelslikemax': 33.0,
#    'feelslikemin': 21.6,
#    'feelslike': 26.4,
#    'dew': 20.2,
#    'humidity': 48.4,
#    'precip': 0.01,
#    'precipprob': 9.0,
#    'precipcover': None,
#    'preciptype': ['snow'],
#    'snow': 0.0,
#    'snowdepth': 30.3,
#    'windgust': 11.4,
#    'windspeed': 5.8,
#    'winddir': 291.3,
#    'pressure': 1019.8,
#    'cloudcover': 56.2,
#    'visibility': 8.4,
#    'solarradiation': 105.7,
#    'solarenergy': 8.8,
#    'uvindex': 4.0,
#    'severerisk': 10.0,
#    'sunrise': '07:09:11',
#    'sunriseEpoch': 1642432151,
#    'sunset': '17:03:34',
#    'sunsetEpoch': 1642467814,
#    'moonphase': 0.5,
#    'conditions': 'Partially cloudy',
#    'description': 'Partly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'stations': None,
#    'source': 'fcst',
#    'hours': [{'datetime': '00:00:00',
#      'datetimeEpoch': 1642406400,
#      'temp': 29.0,
#      'feelslike': 23.9,
#      'humidity': 35.0,
#      'dew': 15.9,
#      'precip': 0.0,
#      'precipprob': 1.0,
#      'snow': 0.0,
#      'snowdepth': 32.5,
#      'preciptype': None,
#      'windgust': 8.1,
#      'windspeed': 4.7,
#      'winddir': 300.0,
#      'pressure': 1022.0,
#      'visibility': 15.0,
#      'cloudcover': 43.0,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '01:00:00',
#      'datetimeEpoch': 1642410000,
#      'temp': 28.7,
#      'feelslike': 23.0,
#      'humidity': 35.0,
#      'dew': 15.9,
#      'precip': 0.0,
#      'precipprob': 1.7,
#      'snow': 0.0,
#      'snowdepth': 32.5,
#      'preciptype': None,
#      'windgust': 8.5,
#      'windspeed': 5.1,
#      'winddir': 300.0,
#      'pressure': 1022.0,
#      'visibility': 14.4,
#      'cloudcover': 46.0,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '02:00:00',
#      'datetimeEpoch': 1642413600,
#      'temp': 28.3,
#      'feelslike': 22.4,
#      'humidity': 35.0,
#      'dew': 15.2,
#      'precip': 0.0,
#      'precipprob': 2.3,
#      'snow': 0.0,
#      'snowdepth': 32.4,
#      'preciptype': None,
#      'windgust': 8.7,
#      'windspeed': 5.4,
#      'winddir': 300.0,
#      'pressure': 1023.0,
#      'visibility': 14.3,
#      'cloudcover': 49.0,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '03:00:00',
#      'datetimeEpoch': 1642417200,
#      'temp': 27.9,
#      'feelslike': 21.6,
#      'humidity': 37.0,
#      'dew': 15.5,
#      'precip': 0.0,
#      'precipprob': 3.0,
#      'snow': 0.0,
#      'snowdepth': 32.4,
#      'preciptype': None,
#      'windgust': 9.2,
#      'windspeed': 5.8,
#      'winddir': 300.0,
#      'pressure': 1022.0,
#      'visibility': 13.8,
#      'cloudcover': 52.0,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '04:00:00',
#      'datetimeEpoch': 1642420800,
#      'temp': 27.6,
#      'feelslike': 22.0,
#      'humidity': 37.0,
#      'dew': 15.7,
#      'precip': 0.0,
#      'precipprob': 3.0,
#      'snow': 0.0,
#      'snowdepth': 32.4,
#      'preciptype': None,
#      'windgust': 8.5,
#      'windspeed': 4.9,
#      'winddir': 306.7,
#      'pressure': 1022.0,
#      'visibility': 6.5,
#      'cloudcover': 57.0,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '05:00:00',
#      'datetimeEpoch': 1642424400,
#      'temp': 27.4,
#      'feelslike': 22.5,
#      'humidity': 37.0,
#      'dew': 16.4,
#      'precip': 0.0,
#      'precipprob': 3.0,
#      'snow': 0.0,
#      'snowdepth': 32.3,
#      'preciptype': None,
#      'windgust': 7.6,
#      'windspeed': 4.3,
#      'winddir': 313.3,
#      'pressure': 1022.0,
#      'visibility': 8.3,
#      'cloudcover': 62.0,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '06:00:00',
#      'datetimeEpoch': 1642428000,
#      'temp': 27.0,
#      'feelslike': 23.2,
#      'humidity': 40.0,
#      'dew': 17.5,
#      'precip': 0.0,
#      'precipprob': 3.0,
#      'snow': 0.0,
#      'snowdepth': 32.3,
#      'preciptype': None,
#      'windgust': 6.9,
#      'windspeed': 3.4,
#      'winddir': 320.0,
#      'pressure': 1022.0,
#      'visibility': 11.2,
#      'cloudcover': 67.0,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '07:00:00',
#      'datetimeEpoch': 1642431600,
#      'temp': 28.3,
#      'feelslike': 28.3,
#      'humidity': 40.0,
#      'dew': 19.8,
#      'precip': 0.0,
#      'precipprob': 5.0,
#      'snow': 0.0,
#      'snowdepth': 32.2,
#      'preciptype': None,
#      'windgust': 6.5,
#      'windspeed': 2.9,
#      'winddir': 310.0,
#      'pressure': 1021.0,
#      'visibility': 8.8,
#      'cloudcover': 61.0,
#      'solarradiation': 6.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '08:00:00',
#      'datetimeEpoch': 1642435200,
#      'temp': 29.7,
#      'feelslike': 29.7,
#      'humidity': 40.0,
#      'dew': 23.8,
#      'precip': 0.0,
#      'precipprob': 7.0,
#      'snow': 0.0,
#      'snowdepth': 32.2,
#      'preciptype': None,
#      'windgust': 6.3,
#      'windspeed': 2.7,
#      'winddir': 300.0,
#      'pressure': 1019.0,
#      'visibility': 15.0,
#      'cloudcover': 55.0,
#      'solarradiation': 34.0,
#      'solarenergy': 0.1,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '09:00:00',
#      'datetimeEpoch': 1642438800,
#      'temp': 31.0,
#      'feelslike': 31.0,
#      'humidity': 49.0,
#      'dew': 24.9,
#      'precip': 0.0,
#      'precipprob': 9.0,
#      'snow': 0.0,
#      'snowdepth': 32.0,
#      'preciptype': None,
#      'windgust': 5.8,
#      'windspeed': 2.2,
#      'winddir': 290.0,
#      'pressure': 1018.0,
#      'visibility': 15.0,
#      'cloudcover': 49.0,
#      'solarradiation': 74.0,
#      'solarenergy': 0.3,
#      'uvindex': 1.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '10:00:00',
#      'datetimeEpoch': 1642442400,
#      'temp': 32.1,
#      'feelslike': 32.1,
#      'humidity': 49.0,
#      'dew': 25.8,
#      'precip': 0.0,
#      'precipprob': 9.0,
#      'snow': 0.0,
#      'snowdepth': 31.5,
#      'preciptype': None,
#      'windgust': 7.6,
#      'windspeed': 2.7,
#      'winddir': 283.3,
#      'pressure': 1018.0,
#      'visibility': 9.4,
#      'cloudcover': 51.0,
#      'solarradiation': 371.0,
#      'solarenergy': 1.3,
#      'uvindex': 4.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '11:00:00',
#      'datetimeEpoch': 1642446000,
#      'temp': 33.0,
#      'feelslike': 33.0,
#      'humidity': 49.0,
#      'dew': 27.8,
#      'precip': 0.0,
#      'precipprob': 9.0,
#      'snow': 0.0,
#      'snowdepth': 30.5,
#      'preciptype': None,
#      'windgust': 9.6,
#      'windspeed': 2.9,
#      'winddir': 276.7,
#      'pressure': 1017.0,
#      'visibility': 3.0,
#      'cloudcover': 52.0,
#      'solarradiation': 423.0,
#      'solarenergy': 1.5,
#      'uvindex': 4.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '12:00:00',
#      'datetimeEpoch': 1642449600,
#      'temp': 34.1,
#      'feelslike': 31.2,
#      'humidity': 56.0,
#      'dew': 27.9,
#      'precip': 0.0,
#      'precipprob': 9.0,
#      'snow': 0.0,
#      'snowdepth': 29.6,
#      'preciptype': ['snow'],
#      'windgust': 11.4,
#      'windspeed': 3.4,
#      'winddir': 270.0,
#      'pressure': 1016.0,
#      'visibility': 1.1,
#      'cloudcover': 54.0,
#      'solarradiation': 426.0,
#      'solarenergy': 1.5,
#      'uvindex': 4.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '13:00:00',
#      'datetimeEpoch': 1642453200,
#      'temp': 33.7,
#      'feelslike': 30.3,
#      'humidity': 56.0,
#      'dew': 27.6,
#      'precip': 0.0,
#      'precipprob': 7.3,
#      'snow': 0.0,
#      'snowdepth': 28.9,
#      'preciptype': ['snow'],
#      'windgust': 11.4,
#      'windspeed': 3.8,
#      'winddir': 270.0,
#      'pressure': 1016.0,
#      'visibility': 0.8,
#      'cloudcover': 57.0,
#      'solarradiation': 402.0,
#      'solarenergy': 1.4,
#      'uvindex': 4.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'fog',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '14:00:00',
#      'datetimeEpoch': 1642456800,
#      'temp': 33.3,
#      'feelslike': 29.4,
#      'humidity': 56.0,
#      'dew': 26.0,
#      'precip': 0.0,
#      'precipprob': 5.7,
#      'snow': 0.0,
#      'snowdepth': 28.3,
#      'preciptype': ['snow'],
#      'windgust': 11.4,
#      'windspeed': 4.3,
#      'winddir': 270.0,
#      'pressure': 1016.0,
#      'visibility': 3.9,
#      'cloudcover': 61.0,
#      'solarradiation': 372.0,
#      'solarenergy': 1.3,
#      'uvindex': 4.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '15:00:00',
#      'datetimeEpoch': 1642460400,
#      'temp': 33.0,
#      'feelslike': 28.5,
#      'humidity': 61.0,
#      'dew': 24.9,
#      'precip': 0.0,
#      'precipprob': 4.0,
#      'snow': 0.0,
#      'snowdepth': 28.3,
#      'preciptype': None,
#      'windgust': 11.4,
#      'windspeed': 4.7,
#      'winddir': 270.0,
#      'pressure': 1016.0,
#      'visibility': 10.7,
#      'cloudcover': 64.0,
#      'solarradiation': 333.0,
#      'solarenergy': 1.2,
#      'uvindex': 3.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '16:00:00',
#      'datetimeEpoch': 1642464000,
#      'temp': 32.1,
#      'feelslike': 27.7,
#      'humidity': 61.0,
#      'dew': 22.0,
#      'precip': 0.0,
#      'precipprob': 9.0,
#      'snow': 0.0,
#      'snowdepth': 28.3,
#      'preciptype': None,
#      'windgust': 10.5,
#      'windspeed': 4.5,
#      'winddir': 275.0,
#      'pressure': 1017.0,
#      'visibility': 10.1,
#      'cloudcover': 63.0,
#      'solarradiation': 39.0,
#      'solarenergy': 0.1,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '17:00:00',
#      'datetimeEpoch': 1642467600,
#      'temp': 31.4,
#      'feelslike': 27.1,
#      'humidity': 61.0,
#      'dew': 18.2,
#      'precip': 0.0,
#      'precipprob': 9.0,
#      'snow': 0.0,
#      'snowdepth': 28.3,
#      'preciptype': None,
#      'windgust': 9.6,
#      'windspeed': 4.3,
#      'winddir': 280.0,
#      'pressure': 1020.0,
#      'visibility': 5.7,
#      'cloudcover': 62.0,
#      'solarradiation': 20.0,
#      'solarenergy': 0.1,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '18:00:00',
#      'datetimeEpoch': 1642471200,
#      'temp': 30.5,
#      'feelslike': 26.3,
#      'humidity': 61.0,
#      'dew': 18.9,
#      'precip': 0.01,
#      'precipprob': 9.0,
#      'snow': 0.0,
#      'snowdepth': 28.2,
#      'preciptype': None,
#      'windgust': 8.7,
#      'windspeed': 4.0,
#      'winddir': 285.0,
#      'pressure': 1020.0,
#      'visibility': 0.4,
#      'cloudcover': 61.0,
#      'solarradiation': 13.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'fog',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '19:00:00',
#      'datetimeEpoch': 1642474800,
#      'temp': 29.6,
#      'feelslike': 25.5,
#      'humidity': 61.0,
#      'dew': 19.1,
#      'precip': 0.0,
#      'precipprob': 9.0,
#      'snow': 0.0,
#      'snowdepth': 28.2,
#      'preciptype': None,
#      'windgust': 7.6,
#      'windspeed': 3.8,
#      'winddir': 290.0,
#      'pressure': 1020.0,
#      'visibility': 1.1,
#      'cloudcover': 60.0,
#      'solarradiation': 10.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '20:00:00',
#      'datetimeEpoch': 1642478400,
#      'temp': 28.8,
#      'feelslike': 25.0,
#      'humidity': 61.0,
#      'dew': 17.3,
#      'precip': 0.0,
#      'precipprob': 9.0,
#      'snow': 0.0,
#      'snowdepth': 28.2,
#      'preciptype': None,
#      'windgust': 6.7,
#      'windspeed': 3.6,
#      'winddir': 295.0,
#      'pressure': 1021.0,
#      'visibility': 7.7,
#      'cloudcover': 59.0,
#      'solarradiation': 8.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '21:00:00',
#      'datetimeEpoch': 1642482000,
#      'temp': 27.9,
#      'feelslike': 24.2,
#      'humidity': 48.0,
#      'dew': 17.0,
#      'precip': 0.0,
#      'precipprob': 9.0,
#      'snow': 0.0,
#      'snowdepth': 28.2,
#      'preciptype': None,
#      'windgust': 5.8,
#      'windspeed': 3.4,
#      'winddir': 300.0,
#      'pressure': 1021.0,
#      'visibility': 9.5,
#      'cloudcover': 58.0,
#      'solarradiation': 6.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '22:00:00',
#      'datetimeEpoch': 1642485600,
#      'temp': 27.6,
#      'feelslike': 23.2,
#      'humidity': 48.0,
#      'dew': 16.4,
#      'precip': 0.0,
#      'precipprob': 9.0,
#      'snow': 0.0,
#      'snowdepth': 28.2,
#      'preciptype': None,
#      'windgust': 6.3,
#      'windspeed': 3.8,
#      'winddir': 295.0,
#      'pressure': 1022.0,
#      'visibility': 10.3,
#      'cloudcover': 54.0,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '23:00:00',
#      'datetimeEpoch': 1642489200,
#      'temp': 27.2,
#      'feelslike': 22.3,
#      'humidity': 48.0,
#      'dew': 15.9,
#      'precip': 0.0,
#      'precipprob': 9.0,
#      'snow': 0.0,
#      'snowdepth': 28.1,
#      'preciptype': None,
#      'windgust': 6.5,
#      'windspeed': 4.3,
#      'winddir': 290.0,
#      'pressure': 1022.0,
#      'visibility': 5.9,
#      'cloudcover': 51.0,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Partially cloudy',
#      'icon': 'partly-cloudy-night',
#      'stations': None,
#      'source': 'fcst'}]},
#   {'datetime': '2022-01-18',
#    'datetimeEpoch': 1642492800,
#    'tempmax': 31.0,
#    'tempmin': 26.0,
#    'temp': 28.3,
#    'feelslikemax': 30.6,
#    'feelslikemin': 19.2,
#    'feelslike': 24.5,
#    'dew': 17.9,
#    'humidity': 51.3,
#    'precip': 0.0,
#    'precipprob': 9.0,
#    'precipcover': None,
#    'preciptype': ['snow'],
#    'snow': 0.0,
#    'snowdepth': 26.5,
#    'windgust': 9.2,
#    'windspeed': 5.8,
#    'winddir': 227.5,
#    'pressure': 1020.5,
#    'cloudcover': 35.6,
#    'visibility': 10.2,
#    'solarradiation': 131.5,
#    'solarenergy': 11.2,
#    'uvindex': 5.0,
#    'severerisk': 10.0,
#    'sunrise': '07:08:46',
# ...
#    'icon': 'snow',
#    'stations': None,
#    'source': 'fcst',
#    'hours': [{'datetime': '00:00:00',
#      'datetimeEpoch': 1643443200,
#      'temp': 29.0,
#      'feelslike': 22.3,
#      'humidity': 98.6,
#      'dew': 28.7,
#      'precip': 0.07,
#      'precipprob': 4.8,
#      'snow': 0.5,
#      'snowdepth': 18.4,
#      'preciptype': ['snow'],
#      'windgust': 9.4,
#      'windspeed': 6.5,
#      'winddir': 189.8,
#      'pressure': 1017.0,
#      'visibility': 0.0,
#      'cloudcover': 100.0,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'snow',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '01:00:00',
#      'datetimeEpoch': 1643446800,
#      'temp': 29.1,
#      'feelslike': 22.5,
#      'humidity': 98.6,
#      'dew': 28.7,
#      'precip': 0.02,
#      'precipprob': 4.8,
#      'snow': 0.1,
#      'snowdepth': 18.5,
#      'preciptype': None,
#      'windgust': 9.2,
#      'windspeed': 6.3,
#      'winddir': 189.7,
#      'pressure': 1016.7,
#      'visibility': 0.0,
#      'cloudcover': 100.0,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'snow',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '02:00:00',
#      'datetimeEpoch': 1643450400,
#      'temp': 29.1,
#      'feelslike': 22.7,
#      'humidity': 98.5,
#      'dew': 28.7,
#      'precip': 0.02,
#      'precipprob': 4.8,
#      'snow': 0.1,
#      'snowdepth': 18.7,
#      'preciptype': None,
#      'windgust': 9.1,
#      'windspeed': 6.2,
#      'winddir': 189.5,
#      'pressure': 1016.3,
#      'visibility': 0.0,
#      'cloudcover': 99.9,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'snow',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '03:00:00',
#      'datetimeEpoch': 1643454000,
#      'temp': 29.2,
#      'feelslike': 22.9,
#      'humidity': 98.5,
#      'dew': 28.7,
#      'precip': 0.02,
#      'precipprob': 4.8,
#      'snow': 0.1,
#      'snowdepth': 18.8,
#      'preciptype': ['snow'],
#      'windgust': 8.9,
#      'windspeed': 6.0,
#      'winddir': 189.4,
#      'pressure': 1016.0,
#      'visibility': 0.0,
#      'cloudcover': 99.9,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'snow',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '04:00:00',
#      'datetimeEpoch': 1643457600,
#      'temp': 28.9,
#      'feelslike': 22.7,
#      'humidity': 98.3,
#      'dew': 28.4,
#      'precip': 0.01,
#      'precipprob': 14.3,
#      'snow': 0.1,
#      'snowdepth': 18.8,
#      'preciptype': None,
#      'windgust': 9.2,
#      'windspeed': 5.8,
#      'winddir': 181.6,
#      'pressure': 1016.0,
#      'visibility': 0.0,
#      'cloudcover': 99.4,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'snow',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '05:00:00',
#      'datetimeEpoch': 1643461200,
#      'temp': 28.6,
#      'feelslike': 22.5,
#      'humidity': 98.2,
#      'dew': 28.2,
#      'precip': 0.01,
#      'precipprob': 14.3,
#      'snow': 0.1,
#      'snowdepth': 18.9,
#      'preciptype': None,
#      'windgust': 9.5,
#      'windspeed': 5.6,
#      'winddir': 173.7,
#      'pressure': 1016.0,
#      'visibility': 0.0,
#      'cloudcover': 98.9,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'snow',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '06:00:00',
#      'datetimeEpoch': 1643464800,
#      'temp': 28.3,
#      'feelslike': 22.4,
#      'humidity': 98.0,
#      'dew': 27.9,
#      'precip': 0.01,
#      'precipprob': 14.3,
#      'snow': 0.1,
#      'snowdepth': 19.0,
#      'preciptype': ['snow'],
#      'windgust': 9.8,
#      'windspeed': 5.4,
#      'winddir': 165.9,
#      'pressure': 1016.0,
#      'visibility': 0.1,
#      'cloudcover': 98.4,
#      'solarradiation': 0.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'snow',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '07:00:00',
#      'datetimeEpoch': 1643468400,
#      'temp': 29.0,
#      'feelslike': 22.5,
#      'humidity': 98.6,
#      'dew': 28.8,
#      'precip': 0.02,
#      'precipprob': 14.3,
#      'snow': 0.1,
#      'snowdepth': 19.1,
#      'preciptype': None,
#      'windgust': 10.1,
#      'windspeed': 6.2,
#      'winddir': 172.5,
#      'pressure': 1015.7,
#      'visibility': 0.0,
#      'cloudcover': 98.9,
#      'solarradiation': 8.7,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'snow',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '08:00:00',
#      'datetimeEpoch': 1643472000,
#      'temp': 29.8,
#      'feelslike': 22.8,
#      'humidity': 99.2,
#      'dew': 29.6,
#      'precip': 0.02,
#      'precipprob': 14.3,
#      'snow': 0.1,
#      'snowdepth': 19.3,
#      'preciptype': None,
#      'windgust': 10.3,
#      'windspeed': 7.0,
#      'winddir': 179.2,
#      'pressure': 1015.3,
#      'visibility': 0.0,
#      'cloudcover': 99.5,
#      'solarradiation': 17.3,
#      'solarenergy': 0.1,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'snow',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '09:00:00',
#      'datetimeEpoch': 1643475600,
#      'temp': 30.5,
#      'feelslike': 23.1,
#      'humidity': 99.8,
#      'dew': 30.5,
#      'precip': 0.02,
#      'precipprob': 14.3,
#      'snow': 0.1,
#      'snowdepth': 19.4,
#      'preciptype': ['snow'],
#      'windgust': 10.5,
#      'windspeed': 7.8,
#      'winddir': 185.8,
#      'pressure': 1015.0,
#      'visibility': 0.0,
#      'cloudcover': 100.0,
#      'solarradiation': 26.0,
#      'solarenergy': 0.1,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'snow',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '10:00:00',
#      'datetimeEpoch': 1643479200,
#      'temp': 30.1,
#      'feelslike': 22.5,
#      'humidity': 99.3,
#      'dew': 29.9,
#      'precip': 0.02,
#      'precipprob': 28.6,
#      'snow': 0.0,
#      'snowdepth': 19.3,
#      'preciptype': None,
#      'windgust': 11.3,
#      'windspeed': 8.1,
#      'winddir': 187.9,
#      'pressure': 1014.3,
#      'visibility': 0.0,
#      'cloudcover': 100.0,
#      'solarradiation': 70.3,
#      'solarenergy': 0.3,
#      'uvindex': 1.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'cloudy',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '11:00:00',
#      'datetimeEpoch': 1643482800,
#      'temp': 29.7,
#      'feelslike': 21.9,
#      'humidity': 98.8,
#      'dew': 29.4,
#      'precip': 0.02,
#      'precipprob': 28.6,
#      'snow': 0.0,
#      'snowdepth': 19.1,
#      'preciptype': None,
#      'windgust': 12.0,
#      'windspeed': 8.3,
#      'winddir': 190.1,
#      'pressure': 1013.7,
#      'visibility': 0.0,
#      'cloudcover': 100.0,
#      'solarradiation': 114.7,
#      'solarenergy': 0.4,
#      'uvindex': 1.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'cloudy',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '12:00:00',
#      'datetimeEpoch': 1643486400,
#      'temp': 29.4,
#      'feelslike': 21.4,
#      'humidity': 98.3,
#      'dew': 28.8,
#      'precip': 0.02,
#      'precipprob': 28.6,
#      'snow': 0.0,
#      'snowdepth': 19.0,
#      'preciptype': ['snow'],
#      'windgust': 12.8,
#      'windspeed': 8.5,
#      'winddir': 192.2,
#      'pressure': 1013.0,
#      'visibility': 0.1,
#      'cloudcover': 100.0,
#      'solarradiation': 159.0,
#      'solarenergy': 0.6,
#      'uvindex': 2.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'fog',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '13:00:00',
#      'datetimeEpoch': 1643490000,
#      'temp': 29.3,
#      'feelslike': 21.3,
#      'humidity': 98.4,
#      'dew': 28.8,
#      'precip': 0.02,
#      'precipprob': 28.6,
#      'snow': 0.0,
#      'snowdepth': 18.9,
#      'preciptype': None,
#      'windgust': 12.2,
#      'windspeed': 8.4,
#      'winddir': 193.7,
#      'pressure': 1012.0,
#      'visibility': 0.0,
#      'cloudcover': 100.0,
#      'solarradiation': 159.7,
#      'solarenergy': 0.6,
#      'uvindex': 2.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'cloudy',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '14:00:00',
#      'datetimeEpoch': 1643493600,
#      'temp': 29.3,
#      'feelslike': 21.3,
#      'humidity': 98.5,
#      'dew': 28.7,
#      'precip': 0.02,
#      'precipprob': 28.6,
#      'snow': 0.0,
#      'snowdepth': 18.8,
#      'preciptype': None,
#      'windgust': 11.7,
#      'windspeed': 8.4,
#      'winddir': 195.3,
#      'pressure': 1011.0,
#      'visibility': 0.0,
#      'cloudcover': 100.0,
#      'solarradiation': 160.3,
#      'solarenergy': 0.6,
#      'uvindex': 2.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'cloudy',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '15:00:00',
#      'datetimeEpoch': 1643497200,
#      'temp': 29.2,
#      'feelslike': 21.3,
#      'humidity': 98.6,
#      'dew': 28.7,
#      'precip': 0.02,
#      'precipprob': 28.6,
#      'snow': 0.0,
#      'snowdepth': 18.7,
#      'preciptype': ['snow'],
#      'windgust': 11.2,
#      'windspeed': 8.3,
#      'winddir': 196.8,
#      'pressure': 1010.0,
#      'visibility': 0.0,
#      'cloudcover': 100.0,
#      'solarradiation': 161.0,
#      'solarenergy': 0.6,
#      'uvindex': 2.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'cloudy',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '16:00:00',
#      'datetimeEpoch': 1643500800,
#      'temp': 28.6,
#      'feelslike': 20.3,
#      'humidity': 98.6,
#      'dew': 28.1,
#      'precip': 0.1,
#      'precipprob': 28.6,
#      'snow': 0.7,
#      'snowdepth': 19.5,
#      'preciptype': None,
#      'windgust': 12.8,
#      'windspeed': 8.7,
#      'winddir': 187.3,
#      'pressure': 1009.3,
#      'visibility': 0.0,
#      'cloudcover': 100.0,
#      'solarradiation': 109.7,
#      'solarenergy': 0.4,
#      'uvindex': 1.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'snow',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '17:00:00',
#      'datetimeEpoch': 1643504400,
#      'temp': 28.0,
#      'feelslike': 19.3,
#      'humidity': 98.5,
#      'dew': 27.6,
#      'precip': 0.1,
#      'precipprob': 28.6,
#      'snow': 0.7,
#      'snowdepth': 20.2,
#      'preciptype': None,
#      'windgust': 14.5,
#      'windspeed': 9.2,
#      'winddir': 177.7,
#      'pressure': 1008.7,
#      'visibility': 0.0,
#      'cloudcover': 100.0,
#      'solarradiation': 58.3,
#      'solarenergy': 0.2,
#      'uvindex': 1.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'snow',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '18:00:00',
#      'datetimeEpoch': 1643508000,
#      'temp': 27.4,
#      'feelslike': 18.3,
#      'humidity': 98.5,
#      'dew': 27.0,
#      'precip': 0.1,
#      'precipprob': 28.6,
#      'snow': 0.7,
#      'snowdepth': 21.0,
#      'preciptype': ['snow'],
#      'windgust': 16.1,
#      'windspeed': 9.6,
#      'winddir': 168.2,
#      'pressure': 1008.0,
#      'visibility': 0.0,
#      'cloudcover': 100.0,
#      'solarradiation': 7.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'snow',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '19:00:00',
#      'datetimeEpoch': 1643511600,
#      'temp': 26.6,
#      'feelslike': 17.5,
#      'humidity': 98.0,
#      'dew': 26.0,
#      'precip': 0.2,
#      'precipprob': 28.6,
#      'snow': 1.7,
#      'snowdepth': 22.7,
#      'preciptype': None,
#      'windgust': 19.5,
#      'windspeed': 9.2,
#      'winddir': 172.3,
#      'pressure': 1008.0,
#      'visibility': 0.0,
#      'cloudcover': 100.0,
#      'solarradiation': 5.7,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'snow',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '20:00:00',
#      'datetimeEpoch': 1643515200,
#      'temp': 25.7,
#      'feelslike': 16.7,
#      'humidity': 97.5,
#      'dew': 25.0,
#      'precip': 0.2,
#      'precipprob': 28.6,
#      'snow': 1.7,
#      'snowdepth': 24.4,
#      'preciptype': None,
#      'windgust': 23.0,
#      'windspeed': 8.7,
#      'winddir': 176.4,
#      'pressure': 1008.0,
#      'visibility': 0.0,
#      'cloudcover': 100.0,
#      'solarradiation': 4.3,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'snow',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '21:00:00',
#      'datetimeEpoch': 1643518800,
#      'temp': 24.9,
#      'feelslike': 16.0,
#      'humidity': 97.0,
#      'dew': 24.0,
#      'precip': 0.2,
#      'precipprob': 28.6,
#      'snow': 1.7,
#      'snowdepth': 26.1,
#      'preciptype': ['snow'],
#      'windgust': 26.4,
#      'windspeed': 8.3,
#      'winddir': 180.5,
#      'pressure': 1008.0,
#      'visibility': 0.0,
#      'cloudcover': 100.0,
#      'solarradiation': 3.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'snow',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '22:00:00',
#      'datetimeEpoch': 1643522400,
#      'temp': 24.7,
#      'feelslike': 15.9,
#      'humidity': 97.0,
#      'dew': 23.8,
#      'precip': 0.12,
#      'precipprob': 33.2,
#      'snow': 1.0,
#      'snowdepth': 27.1,
#      'preciptype': None,
#      'windgust': 21.3,
#      'windspeed': 8.1,
#      'winddir': 189.1,
#      'pressure': 1007.7,
#      'visibility': 0.0,
#      'cloudcover': 100.0,
#      'solarradiation': 2.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'snow',
#      'stations': None,
#      'source': 'fcst'},
#     {'datetime': '23:00:00',
#      'datetimeEpoch': 1643526000,
#      'temp': 24.5,
#      'feelslike': 15.8,
#      'humidity': 97.1,
#      'dew': 23.6,
#      'precip': 0.12,
#      'precipprob': 33.2,
#      'snow': 1.0,
#      'snowdepth': 28.1,
#      'preciptype': None,
#      'windgust': 16.3,
#      'windspeed': 8.0,
#      'winddir': 197.6,
#      'pressure': 1007.3,
#      'visibility': 0.0,
#      'cloudcover': 100.0,
#      'solarradiation': 1.0,
#      'solarenergy': 0.0,
#      'uvindex': 0.0,
#      'severerisk': 10.0,
#      'conditions': 'Overcast',
#      'icon': 'snow',
#      'stations': None,
#      'source': 'fcst'}]}],
#  'alerts': [],
#  'stations': {'SE388': {'distance': 8233.0,
#    'latitude': 37.641,
#    'longitude': -118.907,
#    'useCount': 0,
#    'id': 'SE388',
#    'name': 'SCE Hot Creek CA US SC-EDISON',
#    'quality': 0,
#    'contribution': 0.0},
#   'KBIH': {'distance': 64096.0,
#    'latitude': 37.36,
#    'longitude': -118.37,
#    'useCount': 0,
#    'id': 'KBIH',
#    'name': 'KBIH',
#    'quality': 100,
#    'contribution': 0.0},
#   'KMMH': {'distance': 15521.0,
#    'latitude': 37.61,
#    'longitude': -118.83,
#    'useCount': 0,
#    'id': 'KMMH',
#    'name': 'KMMH',
#    'quality': 97,
#    'contribution': 0.0},
#   'SE514': {'distance': 773.0,
#    'latitude': 37.65,
#    'longitude': -119.007,
#    'useCount': 0,
#    'id': 'SE514',
#    'name': 'SCE Ski Back Trail CA US SC-EDISON',
#    'quality': 0,
#    'contribution': 0.0}},
#  'currentConditions': {'datetime': '09:00:00',
#   'datetimeEpoch': 1642266000,
#   'temp': 30.8,
#   'feelslike': 30.8,
#   'humidity': 27.3,
#   'dew': 1.0,
#   'precip': 0.0,
#   'precipprob': None,
#   'snow': None,
#   'snowdepth': 0.0,
#   'preciptype': None,
#   'windgust': 3.4,
#   'windspeed': 2.7,
#   'winddir': 283.0,
#   'pressure': 1030.9,
#   'visibility': 9.9,
#   'cloudcover': 0.0,
#   'solarradiation': None,
#   'solarenergy': None,
#   'uvindex': None,
#   'conditions': 'Clear',
#   'icon': 'clear-day',
#   'stations': ['KBIH', 'SE514', 'KMMH'],
#   'sunrise': '07:09:55',
#   'sunriseEpoch': 1642259395,
#   'sunset': '17:01:28',
#   'sunsetEpoch': 1642294888,
#   'moonphase': 0.47}}
